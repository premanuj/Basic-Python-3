# %% [markdown]
# # COURSE OF CONTENT
#
#
# 1. Python is all about object
#
# 2. variable declarations
#
# 3. Datatypes in python
#
#     a. Numbers
#         - int, float, long, complex e.t.c...
#
#     b. String,
#     c. List,
#     d. Tuple,
#     e. Set,
#     f. Dictionary,
#
# 4. data unpacking & list slicing
#
# 5. loops and control statements
#
# 6. List and Dictionary Comprehension
#
# 7. Lambda, map and filter functions
#
# 8. Some usefull builtin functions
#
#     - range
#     - enumerate
#     - zip
#     - sum
#     - sorted
#     - isinstance etc...
#
# 9. Enhancing basic python
#
#     -explore collections module
#         defaultdict, OrderedDict, namedtuple, Counter, dequeue
#
#     -explore itertools module
#
# 10. functions
#
# 11. heart of python
#
#     -generators
#
#     -decorators
#
# 12. class and objects
#
#     -definig class and objects
#
#     -properties and methods
#
#     Three types of methods:
#         -instance method
#         -classmethod
#         -staticmethod
